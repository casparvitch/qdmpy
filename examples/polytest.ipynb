# %%
import qdmpy
import qdmpy.plot
import qdmpy.shared.polygon as qp

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as pl

# %%
numpy_txt_file_path = "/home/samsc/ResearchData/test_images/mz_test/ODMR - Pulsed_10_Full_bin_8/field/sig_sub_ref/sig_sub_ref_bnv_0.txt"
json_output_path = "/home/samsc/src/nv/qdmpy_proj/qdmpy_git/examples/polytest.json"
json_input_path = None
mean_plus_minus = 0.2

# %%
pgon_lst = qp.polygon_selector(numpy_txt_file_path,
    json_output_path=json_output_path,
    json_input_path=json_input_path,
    mean_plus_minus=mean_plus_minus)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-555ad31ec5df> in <module>
# ----> 1 pgon_lst = qp.polygon_selector(numpy_txt_file_path,
#       2     json_output_path=json_output_path,
#       3     json_input_path=json_input_path,
#       4     mean_plus_minus=mean_plus_minus)
#
# ~/.local/lib/python3.8/site-packages/qdmpy/shared/polygon.py in polygon_selector(numpy_txt_file_path, json_output_path, json_input_path, mean_plus_minus, strict_range, print_help, **kwargs)
#     509     pgons = psw.get_polygons_lst()
#     510     if len(pgons) < 1:
# --> 511         raise RuntimeError("You didn't define any polygons")
#     512
#     513     # exclude polygons with nodes < 3
#
# RuntimeError: You didn't define any polygons
