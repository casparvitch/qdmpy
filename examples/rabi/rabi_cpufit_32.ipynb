# %%
import qdmpy
import qdmpy.pl
import qdmpy.plot
import qdmpy.field
import qdmpy.source

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
# '%matplotlib widget' allows interactive plots in jupyterlab
# use ''%matplotlib inline' to allow export to pdf
# %matplotlib widget

# %%
exec(open('../TEST_DATA_PATH.py').read())

# %% [markdown]
# ### Load raw data

# %%
options_dict = {
    "base_dir": TEST_DATA_PATH,
    "filepath": "rabi_test/Rabi_32",
    "custom_output_dir_suffix": "_{fit_backend}_bin_{total_bin}",
    "additional_bins": 4,
       
    "system_name": "Zyla",

    "ROI": "Full", 
    
    "AOI_1_start":  [40, 65],
    "AOI_1_end":    [50,  75], 
    "AOI_2_start":  [20, 100],
    "AOI_2_end":    [30, 110], 
    "single_pixel_check": [90//2, 150//2],
    
    "remove_start_sweep": 1,
    
    "show_tick_marks": True,
    
    "fit_backend": "cpufit",
    "fit_backend_comparison": ["cpufit", "scipyfit"],
    "fit_pl_pixels": True, 
    "force_fit": True, 
    
    "use_ROI_avg_fit_res_for_all_pixels": True,
    
    "scipyfit_sub_threads": 2, 

    "fit_functions":  {"constant": 1, "damped_rabi": 1},
    
    "normalisation": "div",
    
    "rabi_freq_guess": 10e6,
    "rabi_t_offset_guess": 20e-9, 
    "rabi_amp_guess": 0.0015, 
    "rabi_decay_time_guess": 1e-6,
    
    "rabi_freq_bounds": [1e1, 1e9],
    "rabi_t_offset_bounds": [1e-9, 1e-6],
    "rabi_amp_bounds": [-1, 1],
    "rabi_decay_time_bounds": [1e-9, 1e-4],
    
    "constant_guess": 0.998,
    "constant_bounds": [0, 2],
    
    "save_fig_type": "png",
    
    "colormap_range_dicts": {
        "residual_images": {
            "type": "percentile",
            "values": [2, 98]
        },
        "sigma_images": {
            "type": "percentile",
            "values": [2, 98]
        },
        "param_images": {
            "type": "percentile",
            "values": [10, 90]
        },
    },
    "mpl_rcparams": {
        "legend.loc": "upper right",
    }
}

# if you want to use a reference experiment {ensure you run this even if 'None' as it sets up output dirs etc.}
ref_options_dir = None

# %%
options, ref_options = qdmpy.initialize(
    options_dict=options_dict,
    ref_options_dir=ref_options_dir,
    set_mpl_rcparams=True
)
# Out:
# /home/samsc/src/qs/qdmpy_proj/qdmpy_git/src/qdmpy/shared/misc.py:17: QDMPYWarning: Continuing without reference. (No reference chosen or exp_referece_type was 'None')
#   warnings.warn(msg, QDMPYWarning)

# %% [markdown]
# ### Load data

# %%
image, prelim_sweep_list = qdmpy.pl.load_image_and_sweep(options)
PL_image, PL_image_ROI, sig, ref, sig_norm, single_pixel_pl, sweep_list, ROI = qdmpy.pl.reshape_dataset(
        options, image, prelim_sweep_list
    )

ROI_PL_fig = qdmpy.plot.roi_pl_image(options, PL_image)

AOI_PL_fig = qdmpy.plot.aoi_pl_image(options, PL_image_ROI)

AOI_spectra_fig = qdmpy.plot.aoi_spectra(options, sig, ref, sweep_list)

qdmpy.pl.save_pl_data(options, PL_image, PL_image_ROI)

# %% [markdown]
# ### Load reference experiment - note, you can fit in this same notebook!

# %%
# ref_fit_params, ref_sigmas = qdmpy.pl.load_ref_exp_pl_fit_results(ref_options)

# %% [markdown]
# ### Fit AOI, ROI averages, single pixel

# %%
fit_model = qdmpy.pl.define_fit_model(options)
backend_ROI_results_lst = qdmpy.pl.fit_roi_avg_pl(options, sig, ref, sweep_list, fit_model) # if update sig_norm => sig,ref
ROI_fit_fig = qdmpy.plot.roi_avg_fits(options, backend_ROI_results_lst)

fit_result_collection_lst = qdmpy.pl.fit_aois_pl(options, sig, ref, single_pixel_pl, sweep_list, fit_model, backend_ROI_results_lst)
AOI_fit_fig = qdmpy.plot.aoi_spectra_fit(options, sig, ref, sweep_list, fit_result_collection_lst, fit_model)
# Out:
# /home/samsc/src/qs/qdmpy_proj/qdmpy_git/src/qdmpy/pl/gpufit.py:167: UserWarning: CUDA error:
# b'no CUDA-capable device is detected'
#   warn(f"CUDA error:\n{gf.get_last_error()}")
# /home/samsc/src/qs/qdmpy_proj/qdmpy_git/src/qdmpy/pl/scipyfit.py:35: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm  # auto detects jupyter

# %% [markdown]
# ### Fit pixels

# %%
wanted_roi_result = next(
    filter(
        lambda result: result.fit_backend == options["fit_backend"], backend_ROI_results_lst
    )
) # ROI fit result for chosen fit backend
pixel_fit_params, sigmas = qdmpy.pl.get_pl_fit_result(options, sig_norm, sweep_list, fit_model, wanted_roi_result)

qdmpy.pl.save_pl_fit_results(options, pixel_fit_params)
qdmpy.pl.save_pl_fit_sigmas(options, sigmas)

# %%
ref_fit_params, ref_sigmas = qdmpy.pl.load_ref_exp_pl_fit_results(ref_options)

# %% [markdown]
# ### Plot (fit) parameters

# %%
options["colormap_range_dicts"]["param_images"] = {
            "type": "percentile",
            "values": [10, 90],
}

c_fig = qdmpy.plot.pl_param_images(options, fit_model, pixel_fit_params, "constant")
amp_fig = qdmpy.plot.pl_param_images(options, fit_model, pixel_fit_params, "rabi_amp")
decay_fig = qdmpy.plot.pl_param_images(options, fit_model, pixel_fit_params, "rabi_decay_time")
toffset_fig = qdmpy.plot.pl_param_images(options, fit_model, pixel_fit_params, "rabi_t_offset")
residual_fig = qdmpy.plot.pl_param_images(options, fit_model, pixel_fit_params, "residual")

# %%
options["colormap_range_dicts"]["param_images"] = {
            "type": "percentile",
            "values": [2, 98],
}
exp_fig = qdmpy.plot.pl_param_images(options, fit_model, pixel_fit_params, "rabi_freq")

# %%
qdmpy.save_options(options)
import qdmpy.shared.json2dict; print(qdmpy.shared.json2dict.dict_to_json_str(options))
# Out:
# {
#     "base_dir": "/home/samsc/ResearchData/test_images/",
#     "filepath": "/home/samsc/ResearchData/test_images/rabi_test/Rabi_32",
#     "custom_output_dir_prefix": null,
#     "custom_output_dir_suffix": "_{fit_backend}_bin_{total_bin}",
#     "custom_output_dir": null,
#     "ignore_ref": false,
#     "additional_bins": 4,
#     "system_name": "Zyla",
#     "other_measurement_suffixes": ["_T.txt", "_IV.txt"],
#     "remove_start_sweep": 1,
#     "remove_end_sweep": 0,
#     "normalisation": "div",
#     "exp_reference_type": "field",
#     "microscope_setup": {
#         "sensor_pixel_size": 6.5e-06,
#         "default_objective_mag": 4,
#         "default_objective_reference_focal_length": 0.2,
#         "default_camera_tube_lens": 0.3
#     },
#     "pixel_size": null,
#     "objective_mag": null,
#     "objective_reference_focal_length": null,
#     "camera_tube_lens": null,
#     "polygon_nodes_path": null,
#     "mask_polygons_bground": false,
#     "annotate_polygons": false,
#     "ROI": "Full",
#     "ROI_start": 0,
#     "ROI_end": 0,
#     "single_pixel_check": [45, 75],
#     "AOI_1_start": [40, 65],
#     "AOI_1_end": [50, 75],
#     "AOI_2_start": [20, 100],
#     "AOI_2_end": [30, 110],
#     "AOI_3_start": null,
#     "AOI_3_end": null,
#     "AOI_4_start": null,
#     "AOI_4_end": null,
#     "AOI_5_start": null,
#     "AOI_5_end": null,
#     "fit_backend": "cpufit",
#     "fit_backend_comparison": ["cpufit", "scipyfit"],
#     "force_fit": true,
#     "fit_pl_pixels": true,
#     "scramble_pixels": true,
#     "use_ROI_avg_fit_res_for_all_pixels": true,
#     "fit_functions": {"constant": 1, "damped_rabi": 1},
#     "pos_guess": null,
#     "pos_range": 25,
#     "amp_guess": -0.0015,
#     "amp_bounds": [-0.01, -0.0003],
#     "fwhm_guess": 9,
#     "fwhm_bounds": [3, 40],
#     "pos_gauss_guess": null,
#     "pos_gauss_range": 25,
#     "amp_gauss_guess": -0.0015,
#     "amp_gauss_bounds": [-0.01, -0.0003],
#     "fwhm_gauss_guess": 9,
#     "fwhm_gauss_bounds": [3, 40],
#     "c_guess": 1,
#     "c_bounds": [0.95, 1.05],
#     "m_guess": 0,
#     "m_bounds": [-0.0001, 0.0001],
#     "constant_guess": 0.998,
#     "constant_bounds": [0, 2],
#     "rabi_freq_guess": 10000000.0,
#     "rabi_freq_bounds": [10.0, 1000000000.0],
#     "rabi_t_offset_guess": 2e-08,
#     "rabi_t_offset_bounds": [1e-09, 1e-06],
#     "rabi_amp_guess": 0.0015,
#     "rabi_amp_bounds": [-1, 1],
#     "rabi_decay_time_guess": 1e-06,
#     "rabi_decay_time_bounds": [1e-09, 0.0001],
#     "circ_freq_guess": null,
#     "circ_freq_bounds": [null, null],
#     "pos_circ_guess": null,
#     "pos_circ_bounds": [null, null],
#     "amp_circ_guess": null,
#     "amp_circ_bounds": [null, null],
#     "pos_h14_guess": null,
#     "pos_h15_guess": null,
#     "pos_h14_range": 25,
#     "pos_h15_range": 25,
#     "amp_h15_hyp_1_guess": -0.015,
#     "amp_h15_hyp_2_guess": -0.015,
#     "amp_h15_hyp_1_bounds": [-0.1, -0.001],
#     "amp_h15_hyp_2_bounds": [-0.1, -0.001],
#     "amp_h14_hyp_1_guess": -0.015,
#     "amp_h14_hyp_2_guess": -0.015,
#     "amp_h14_hyp_3_guess": -0.015,
#     "amp_h14_hyp_1_bounds": [-0.1, -0.001],
#     "amp_h14_hyp_2_bounds": [-0.1, -0.001],
#     "amp_h14_hyp_3_bounds": [-0.1, -0.001],
#     "fwhm_h15_hyp_1_guess": 3,
#     "fwhm_h15_hyp_2_guess": 3,
#     "fwhm_h15_hyp_1_bounds": [1, 20],
#     "fwhm_h15_hyp_2_bounds": [1, 20],
#     "fwhm_h14_hyp_1_guess": 3,
#     "fwhm_h14_hyp_2_guess": 3,
#     "fwhm_h14_hyp_3_guess": 3,
#     "fwhm_h14_hyp_1_bounds": [1, 20],
#     "fwhm_h14_hyp_2_bounds": [1, 20],
#     "fwhm_h14_hyp_3_bounds": [1, 20],
#     "power_exp_guess": 0.7,
#     "power_exp_bounds": [0.5, 1.0],
#     "charac_exp_t_guess": 0.001,
#     "charac_exp_t_bounds": [0.0001, 0.03],
#     "amp_exp_guess": 0.001,
#     "amp_exp_bounds": [-1, 1],
#     "pos_hBN_guess": null,
#     "pos_hBN_range": null,
#     "amp_hBN_hyp_1_guess": null,
#     "amp_hBN_hyp_2_guess": null,
#     "amp_hBN_hyp_3_guess": null,
#     "amp_hBN_hyp_4_guess": null,
#     "amp_hBN_hyp_5_guess": null,
#     "amp_hBN_hyp_6_guess": null,
#     "amp_hBN_hyp_7_guess": null,
#     "amp_hBN_hyp_1_bounds": null,
#     "amp_hBN_hyp_2_bounds": null,
#     "amp_hBN_hyp_3_bounds": null,
#     "amp_hBN_hyp_4_bounds": null,
#     "amp_hBN_hyp_5_bounds": null,
#     "amp_hBN_hyp_6_bounds": null,
#     "amp_hBN_hyp_7_bounds": null,
#     "fwhm_hBN_hyp_1_guess": null,
#     "fwhm_hBN_hyp_2_guess": null,
#     "fwhm_hBN_hyp_3_guess": null,
#     "fwhm_hBN_hyp_4_guess": null,
#     "fwhm_hBN_hyp_5_guess": null,
#     "fwhm_hBN_hyp_6_guess": null,
#     "fwhm_hBN_hyp_7_guess": null,
#     "fwhm_hBN_hyp_1_bounds": null,
#     "fwhm_hBN_hyp_2_bounds": null,
#     "fwhm_hBN_hyp_3_bounds": null,
#     "fwhm_hBN_hyp_4_bounds": null,
#     "fwhm_hBN_hyp_5_bounds": null,
#     "fwhm_hBN_hyp_6_bounds": null,
#     "fwhm_hBN_hyp_7_bounds": null,
#     "calc_field_pixels": true,
#     "force_field_calc": false,
#     "field_method": "auto_dc",
#     "hamiltonian": "bxyz",
#     "freqs_to_use": [true, true, true, true, true, true, true, true],
#     "single_unv_choice": 0,
#     "diamond_ori": "<100>_<100>",
#     "auto_read_bias": false,
#     "auto_guess_B": true,
#     "use_unvs": false,
#     "unvs": [
#         [0.57735, 0.57735, 0.57735],
#         [-0.57735, 0.57735, 0.57735],
#         [0.57735, -0.57735, 0.57735],
#         [-0.57735, -0.57735, 0.57735]
#     ],
#     "auto_order_unvs": false,
#     "bias_mag": 80,
#     "bias_theta": 15,
#     "bias_phi": 15,
#     "Bx_guess": 10,
#     "Bx_range": 200,
#     "By_guess": 10,
#     "By_range": 200,
#     "Bz_guess": 10,
#     "Bz_range": 200,
#     "D_guess": 2871,
#     "D_range": 500,
#     "scipyfit_method": "trf",
#     "scipyfit_sub_threads": 2,
#     "scipyfit_show_progressbar": true,
#     "scipyfit_use_analytic_jac": true,
#     "scipyfit_verbose_fitting": 0,
#     "scipyfit_fit_jac_acc": "2-point",
#     "scipyfit_fit_gtol": 1e-12,
#     "scipyfit_fit_xtol": 1e-12,
#     "scipyfit_fit_ftol": 1e-12,
#     "scipyfit_scale_x": true,
#     "scipyfit_loss_fn": "linear",
#     "gpufit_tolerance": 1e-12,
#     "gpufit_max_iterations": 50,
#     "gpufit_estimator_id": "LSE",
#     "fourier_pad_mode": "constant",
#     "fourier_pad_factor": 2,
#     "fourier_k_vector_epsilon": 1e-06,
#     "fourier_do_hanning_filter": true,
#     "fourier_high_cutoff": null,
#     "fourier_low_cutoff": null,
#     "NVs_above_sample": true,
#     "source_type": "current_density",
#     "standoff": null,
#     "nv_layer_thickness": null,
#     "recon_methods": ["from_bxy", "from_bz", "from_bnv"],
#     "recon_unv_index": null,
#     "zero_point_normalisation_region": null,
#     "in_plane_mag_norm_number_pixels": null,
#     "magnetization_angle": null,
#     "bfield_bground_method": null,
#     "bfield_bground_params": {},
#     "bnv_bground_method": null,
#     "bnv_bground_params": {},
#     "source_bground_method": null,
#     "source_bground_params": {},
#     "save_plots": true,
#     "show_scalebar": true,
#     "show_tick_marks": true,
#     "annotate_image_regions": true,
#     "save_fig_type": "png",
#     "large_fig_save_type": "png",
#     "colormaps": {
#         "param_images": "viridis",
#         "residual_images": "inferno",
#         "sigma_images": "magma",
#         "pl_images": "Greys_r",
#         "bnv_images": "RdBu_r",
#         "dshift_images": "PRGn",
#         "bfield_images": "bwr",
#         "source_images": "viridis",
#         "current_vector_images": "seismic",
#         "current_norm_images": "turbo",
#         "current_div_images": "coolwarm",
#         "magnetization_images": "PuOr"
#     },
#     "plot_bnv_flip_with_bias_mag": false,
#     "colormap_range_dicts": {
#         "param_images": {"type": "percentile", "values": [2, 98]},
#         "residual_images": {
#             "type": "percentile", "values": [2, 98], "auto_sym_zero": null
#         },
#         "sigma_images": {"type": "percentile", "values": [2, 98]},
#         "pl_images": {"type": "min_max", "auto_sym_zero": null, "values": null},
#         "bnv_images": {"type": "min_max"},
#         "dshift_images": {"type": "min_max"},
#         "bfield_images": {"type": "min_max"},
#         "source_images": {"type": "min_max"},
#         "current_vector_images": {"type": "percentile", "values": [1, 99]},
#         "current_norm_images": {"type": "strict_range", "values": [0, 50]},
#         "current_div_images": {"type": "percentile", "values": [1, 99]},
#         "magnetization_images": {"type": "min_max"}
#     },
#     "mpl_rcparams": {
#         "figure.constrained_layout.use": true,
#         "figure.figsize": [6.4, 4.8],
#         "figure.dpi": 80,
#         "figure.max_open_warning": 30,
#         "lines.linewidth": 0.8,
#         "lines.markersize": 3,
#         "xtick.labelsize": 10,
#         "xtick.major.size": 4,
#         "xtick.direction": "in",
#         "ytick.labelsize": 10,
#         "ytick.direction": "in",
#         "ytick.major.size": 4,
#         "legend.fontsize": "small",
#         "legend.loc": "upper right",
#         "scalebar.location": "lower right",
#         "scalebar.width_fraction": 0.015,
#         "scalebar.box_alpha": 0.5,
#         "scalebar.scale_loc": "top",
#         "scalebar.sep": 1,
#         "axes.formatter.useoffset": false,
#         "axes.formatter.use_mathtext": true,
#         "errorbar.capsize": 3.0
#     },
#     "polygon_patch_params": {
#         "facecolor": null, "edgecolor": "k", "linestyle": "dashed", "fill": false
#     },
#     "AOI_colors": [
#         "blue", "tab:brown", "purple", "darkslategrey", "magenta", "olive", "cyan"
#     ],
#     "fit_backend_colors": {
#         "scipyfit": {
#             "ROIfit_linecolor": "mediumblue",
#             "residual_linecolor": "black",
#             "AOI_ROI_fit_linecolor": "indigo",
#             "AOI_best_fit_linecolor": "crimson"
#         },
#         "gpufit": {
#             "ROIfit_linecolor": "cornflowerblue",
#             "residual_linecolor": "dimgrey",
#             "AOI_ROI_fit_linecolor": "mediumpurple",
#             "AOI_best_fit_linecolor": "coral"
#         },
#         "cpufit": {
#             "ROIfit_linecolor": "lightskyblue",
#             "residual_linecolor": "lightgrey",
#             "AOI_ROI_fit_linecolor": "plum",
#             "AOI_best_fit_linecolor": "goldenrod"
#         }
#     },
#     "streamplot_options": {"density": 3, "linewidth": 1.0, "arrowsize": 0.75},
#     "streamplot_pl_alpha": 1.0,
#     "streamplot_cbar_options": {
#         "alpha_ramp_factor": 2,
#         "low_cutoff": 0.1,
#         "high_cutoff": 1.0,
#         "dynamic_range": 1000
#     },
#     "quiverplot_options": {},
#     "cleaned": true,
#     "system": <qdmpy.system.systems.Zyla object at 0x7fec745195a0>,
#     "used_ref": true,
#     "metadata": {
#         "ImageSizeBytes": 524288.0,
#         "Binning": 0.0,
#         "PixelEncoding": "Mono16",
#         "AOIStride": 1024.0,
#         "AOIWidth": 512.0,
#         "AOIHeight": 512.0,
#         "CCD shutter": "Global",
#         "Exposure time": 0.02,
#         "Optical readout time (s)": 3e-05,
#         "Wait time (s)": 1.5e-06,
#         "Initial polarise pulse (s)": 0.001,
#         "Measurement": 2.0,
#         "Measurement protocol": 1.0,
#         "Microwave power (dBm)": -16.0,
#         "Probe frequency (MHz)": 2092.0,
#         "X pi time (s)": 4e-08,
#         "Y pi time (s)": 4.6e-08,
#         "X pi/2 time (s)": 2e-08,
#         "RF channel": 0.0,
#         "MW2 power (dBm)": -4.615,
#         "MW2 probe frequency (MHz)": 1591.38,
#         "MW2 probe time (s)": 3e-06,
#         "MW2 pi time (s)": 2.6e-07,
#         "Y detuning (s)": 0.0,
#         "Current on/off": false,
#         "Voltage (V)": 3.265122,
#         "Current (A)": 0.0002000094,
#         "Resistance (ohm)": 16324.84,
#         "# of pi pulses": 32.0,
#         "NMR tau": 2.96e-07,
#         "NMR tau 2": 2.96e-07,
#         "# of pi pulses 2": 4.0,
#         "# of pol N": 50.0,
#         "# of read out pulses": 5.0,
#         "# of read out pulses 2": 2.0,
#         "# of prepol N": 200.0,
#         "# of completed sweeps": 97.0,
#         "Time stamp": "19-01-22, 3:50:32 PM"
#     },
#     "threads": 6,
#     "rebinned_image_shape": [128, 128],
#     "reloaded_prev_fit": null,
#     "found_prev_result": false,
#     "found_prev_result_reason": "option 'force_fit' was True",
#     "output_dir": /home/samsc/ResearchData/test_images/rabi_test/Rabi_32_cpufit_bin_0,
#     "data_dir": /home/samsc/ResearchData/test_images/rabi_test/Rabi_32_cpufit_bin_0/data,
#     "fit_param_defn": {
#         "constant_0": "Amplitude (a.u.)",
#         "rabi_freq_0": "Omega (rad/s)",
#         "rabi_t_offset_0": "Tau_0 (s)",
#         "rabi_amp_0": "Amp (a.u.)",
#         "rabi_decay_time_0": "Tau_d (s)"
#     },
#     "total_bin": 0,
#     "original_bin": 0,
#     "ModelID": -2,
#     "CUDA_version_runtime": [-1, 99],
#     "CUDA_version_driver": [11, 8],
#     "fit_time_(s)": 0.5648998489996302,
#     "ham_fit_time_(s)": null,
#     "field_dir": /home/samsc/ResearchData/test_images/rabi_test/Rabi_32_cpufit_bin_0/field,
#     "field_sig_dir": /home/samsc/ResearchData/test_images/rabi_test/Rabi_32_cpufit_bin_0/field/sig,
#     "field_ref_dir": /home/samsc/ResearchData/test_images/rabi_test/Rabi_32_cpufit_bin_0/field/ref_nothing,
#     "field_sig_sub_ref_dir": /home/samsc/ResearchData/test_images/rabi_test/Rabi_32_cpufit_bin_0/field/sig_sub_ref,
#     "field_method_used": null,
#     "field_params": null,
#     "found_prev_field_calc": null,
#     "found_prev_field_calc_reason": null,
#     "polygon_nodes": null,
#     "polygons": null,
#     "source_dir": null,
#     "unvs_used": null,
#     "bias_field_cartesian_gauss": [20.0, 5.3589838486224535, 77.27406610312546],
#     "bias_field_spherical_deg_gauss": [80, 15, 15],
#     "ref_bias_field_cartesian_gauss": null,
#     "ref_bias_field_spherical_deg_gauss": null,
#     "qdmpy_version": "3.0.1",
#     "calculated_raw_pixel_size": 1.0833333333333335e-06,
#     "calculated_binned_pixel_size": 0.0
# }
